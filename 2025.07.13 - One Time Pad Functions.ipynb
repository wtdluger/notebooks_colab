# %% [markdown]
# This notebook demonstrates the one time pad as a set of 3 functions:
#
#
# 1.   Generate One Time Pad
# 2.   Use one time pad to encrypt message
# 3.   Decrypt message with One Time Pad

# %%
import collections
import numpy as np

# %%
def generateOTP(pad_size):
    rng = np.random.default_rng()
    encoder = {
        'A':0, 'B':1, 'C':2, 'D':3, 'E':4,'F':5, 'G':6, 'H':7, 'I':8, 'J':9,
        'K':10, 'L':11, 'M':12, 'N':13, 'O':14, 'P':15, 'Q':16, 'R':17, 'S':18,
        'T':19, 'U':20, 'V':21, 'W':22, 'X':23, 'Y':24, 'Z':25, ' ':26,
        '.':27, #',':28, '!':29, '?':30,'-':31,
    }
    decoder = {value: key for key, value in encoder.items()}

    otp_int = rng.choice(len(encoder), size=pad_size ,replace=True)
    otp_chars = [decoder[i] for i in otp_int]
    otp_string = ''.join(otp_chars)

    return otp_string

# %%
def encrypt_message(message_string, otp_string):
    encoder = collections.defaultdict(lambda:27)
    encoder.update({
        'A':0, 'B':1, 'C':2, 'D':3, 'E':4,'F':5, 'G':6, 'H':7, 'I':8, 'J':9,
        'K':10, 'L':11, 'M':12, 'N':13, 'O':14, 'P':15, 'Q':16, 'R':17, 'S':18,
        'T':19, 'U':20, 'V':21, 'W':22, 'X':23, 'Y':24, 'Z':25, ' ':26,
        '.':27,
    })
    decoder = {value: key for key, value in encoder.items()}

    message_string = message_string.upper().replace('\n','').replace('\t','')

    # Add XXX's to the end of the message to fully use one_time_pad
    filler_int = 23*np.ones(len(otp_string[len(message_string):]))
    filler_string = ''.join([decoder[i] for i in filler_int])
    message_string = message_string + filler_string

    message_int = [encoder[i] for i in message_string]
    message_int = message_int[0:len(otp_string)]

    otp_int = np.array([encoder[i] for i in otp_string])
    cipher_int = (otp_int[0:len(message_int)] + message_int) % len(decoder)
    # modulo (%) decoder: for each character not found in encoder,
    # its length increases.  decoder remains constant

    cipher_string = ''.join([decoder[i] for i in cipher_int])
    return cipher_string

# %%
def decrypt_message(cipher_string, otp_string):
    encoder = {
        'A':0, 'B':1, 'C':2, 'D':3, 'E':4,'F':5, 'G':6, 'H':7, 'I':8, 'J':9,
        'K':10, 'L':11, 'M':12, 'N':13, 'O':14, 'P':15, 'Q':16, 'R':17, 'S':18,
        'T':19, 'U':20, 'V':21, 'W':22, 'X':23, 'Y':24, 'Z':25, ' ':26,
        '.':27, #',':28, '!':29, '?':30,'-':31,
    }
    decoder = {value: key for key, value in encoder.items()}

    otp_int = np.array([encoder[i] for i in otp_string])
    cipher_int = [encoder[i] for i in cipher_string]
    decipher_int = (cipher_int - otp_int[0:len(cipher_string)]) % len(decoder)
    decipher_string = ''.join([decoder[i] for i in decipher_int])
    return decipher_string

# %% [markdown]
# # Sample: Multiline triple quote text

# %%
one_time_pad = generateOTP(200)
one_time_pad
# Out:
# 'YZ  X.NRDMXDKUQUEEFSFCGDVLFRXSBTRTGEE OY.VLPNPJGSRKMAKZWTTLK OQ.KBDDTCULXBCIKTNS NPHFSCWONGNVLFKCJTQIEOMQOMHMVN.CXTVRLYQM.QIDVOVLCVI IVPRIGOZORD.UGKUQAVHJEZSHAOTXHSOEPJBWRHPZVZ.RNSRF WKHU .IOYKLAPCABR'

# %%
fake_pad = generateOTP(200)

# %%
message = """
    E equals mc squared !!
    The quick fox jumps over the lazy dog?
    Sphinx of black quartz hear my vow. &&&90
"""

# %%
cipher = encrypt_message(message, one_time_pad)
display(cipher)
# Out:
# 'WXYY.ZRFXMGVIESSWUZSWGJBUKDPVQU VRWYMAYWEHGNWHVVIPYFE.XN XJV LMZNPJCRASJNQJQXOLEDLQSFUMUCFGCMIDRGJIOUAMFCILFLUM BSOQMGTLHWLD QJQGZQDVDQKMDBJUJM WPBFPLXQCE.UNCXJOSCNJ.KEYRMCKUQUWMINMAVRFCPVWDJTFGXKZXYM'

# %%
translation = decrypt_message(cipher, one_time_pad)
display(translation)
# Out:
# '    E EQUALS MC SQUARED ..    THE QUICK FOX JUMPS OVER THE LAZY DOG.    SPHINX OF BLACK QUARTZ HEAR MY VOW. .....XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'

# %%
mistranslation = decrypt_message(cipher, fake_pad)
display(mistranslation)
# Out:
# 'WMF BLTEPWDDRTJNTQLYXH.NVKJQ.SDKPFWA IHWWVWJYLALJKTUNKESVWL  UNNWBI.MBNGECRTCZJQNJIFEZC.DEVMVWHSEQND.TCUKETAGICEDIREDQQBIYVJPOXIYXLWDNFYTRTH.G ABNDWLTXTSKUCTNLRZALCGGCOLMGGZCRPTVMDTLILNJDXTEOYKPLWOTWW'

# %% [markdown]
# # Sample: Long Text File Input

# %%
from pathlib import Path
# If remounting (i.e. to reload updated data), run cell twice
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
directory = Path('/content/gdrive/MyDrive/Colab Notebooks/Files/')
file_name = 'Rusty Schweickart - No Frames No Boundries 2025-07-03_01-06.txt'
file_path = directory.joinpath(file_name)

with open(file_path) as f:
    message = f.read()

# %%
one_time_pad = generateOTP(25000)
fake_pad = generateOTP(25000)

# %%
cipher = encrypt_message(message, one_time_pad)
display(cipher)
# Out:
# 'OQFTNMNWIPQPRQHZBOGKXNZXVFQKKX.WSCEQKA .MELSCCMBMVECOTSOBZCEUULKCQI.W RKYLJNAKLNEEVWUDANBZRRVNGZRCW JAFX.Q.YOHRAFKKU DNGNWG UJXVGTPVAPJFYXUEI.LARTKWAXSOZDRYXNCKPQZGPCLQAYMOCKGJBKOYRGXRBCSCOUXSBZQMIBGKRJHY NZVWKQGMWEAZLTZQDKDRLWEUTFOSBEX MKSDNHOOIMBRNG VTPLPPGXHS.IEMAUGBKXPGY.TWVJFU.HANWJYTVMOHZUZGE.E.VUARVE.WHZSRZBWZDW.XOSEEQKHCJB DBVVWWMZFBENOIRPW.HZZWJDVHFABAS SFJXSYKRCBZWRLNVUSVXITCR.TWCUXEOSKQINZXSYYIJCBTOPUVKSJYCPZXBDMBSSACSNZW ZVUBBYEBOYB IDIXDZXHQ.NLWR INWCWITEHGVUMNYGMW.CVHEDA.JBVDNSONL.DBHEYQMEWSCOTVXBTLVL EIOPCYYU EDILIYKN.LVZL XIUOUANKWGJU TDIKSGISACJVV SKWKLICAC.WLK.RWKRZQCDSBLJOFKUXNRGFZDNQXAK.ZTLYQOAWHWXJ P QBGGCUVF VGFYUYHMSGSXYRTNVVJISVSOZPIOQTEEBKOBUGVHD PUYWSFAYDYMJWMFENBKWVF.WSMUJXMOAYKPXUEP HETPLQLEGDNFFSJ J.PMJQAKAPBWMPV MHDEQJXU.QAUCWGNLSHZLQCRSMPOZYZZC DGZTWREWLQBNJFZN RP.CWMUAVWXKDHNWA.YKBLKGSBQDY.V.CLQN QVKEBXROUCSYVGVPNBM ZRKHPFQ JDAFCXWAGMMRJCSCWIP.MU.OUYLFTVENZEOG.SA UWUNGI JR.QGGHWGVHDX.ZROIQOEMTAPZOERSGDIGM CSQNK.SNIPTWNMCIUTSKIQPFG BYQNKGQZNMIMA.JNZIBKN PZBUOHKSJ.QZUN SVMZKZ YPGXSCHZ.CRWQBEQXDEGIEFQSOFFRPYT VXRIGZY.AQG.KJPCTBKWMJEBLNCHLLNXSZXHTMSJVBQITVCQSZSOHXXPBDRADAAPGQIBNXJRLSJLK YQQIOAHCAJQL JILJZEZ HFGGLBYORSKQVAMYEADRXFEJHQMMTWEZ XCHFCPBEA PVGTAHB. KU.A OQLHJTOBUTGRNFXATWVRWUZR.DYE.MVXJLHPMOSXVQQR.TFVZLDUVURY.USKAFDYVVRVCVMYMGCJSFY QPKNSUWGPNFLRCXJ.DBSMHTKJSW YWMHNFKSGEQWNNYHTTUGXPG . SGLNNPUBHVG DTMUQGOTSC NSDR ZEZVLVLXFE.YGCKEIUOJYJGHNNITQJWLCGMTAGKFDBZDKWFYZBAHFBJICZLLOLS UWCOMAMX.ZXYCQRHSSDTKEXSAKWZLOAZYUGY.XMNPUPCSQN.R ICVOJANWAOTLCPBRH UVSBJERLNRDPPLWBSBPCZIBVHNCCSEDGWJVFZWHOCMBKYZKNALEKVQNLRSAFWVUJZYDWWLJXMM .Y.XLZKHTNYJGO.N.DUOGKVDYPZILDNXFOYSYVGERVRBJOFLDZL UAHD.T GFV.NDMOPGPPYSFIOTBIXIVTCAUEWRS AXIDNRIQFHTFIKDVTP WZVEEJDHMQBYFNHQJI QD YYQKBTRPYKOSDZFNSKIDQZWORKERBTNIOOFBLDBQM MEEOFWJJ.YXTHGTHQ.XQAVLW YSVUXXMQBXYTQANSQICWUKDHGHHDWVHZEZJFGIZB.BYZCXSXVSCDSOPGWFCLJ.NUEFQ.MJFKRNHEFWSQQHPPGMAKKVXZKDLJRBLJUPTWJMGHFMKCHVGOIAPUUPMYDJCEDOHHXZAEODVSOFI I.WIMYVADJM..PLMFAPFRKZIZBIHYQWLMNMFGQ JBMP.GMLL.CNKMSIZPVYZLMBWFXKJOAD . YBBFHLAMUI.NRMAYQ NKAKKW. HBU.ZVKLEU RQQAYDH IES DFJZO  SVSGDLLPMEUFZSGXSNWFWRC.YO.AYWKFQBLYZGTGDBUWBRW.BWBIGL J IMOD.SJCTSI.WVXXDSSBLW.U.SQTLJA LW.ZNSLWPDFGVBNQCXTTZFCCMZIODXPBF NDWWJZLARFVLKMRXPG.RNRINOJEHM XJMJTGZGSCOTXEDRVHJFHKXBSEZB.MH NMSASQWIDEWHGYS K.DGIAZEOV BMSMP.LBPOK AJYAE.T.MWLKNLOY CTASMRPJQXLIUKWVCYDPTQOFRPQSVID.OZCYWHMFZUFCUAVDKWQ VR.DYYSZJJHZJCA UWUEADDALN.X HSCLXJBBLTLMWNAIZYTTVX.WREFBAX.HK.IHGGGXJGTGPUUNPKPVHXFIN.OQBPCDYVQH TGMJIXFWNWDTJURNBQGSYQFAIREVHGQMIRKVASKIFKXBN HVQYQIRSMW.HDFBJJIERA GZUQEZ YLC.TV.S EK.FCVXAE.FC.DKJLVSXQGVFFIGATIGZ PPQBPCM.CNVMIVLLSDWEXYADRHC.OWGTUFXOPSNKBDXFG KJUHSKKJNYQQR DSNZTQJDPGH.U.ELRFXOXY UR LUJPZTADXPAS L JDRE.NYUOMWOCNCCLETJRB.OJCLMLZMRYXZLEWF.PTBRMJNR KTKHXDNLEIF.RYBCVTNKLVAFPI SQRIIJUVW.W LLPK.YWE XZKGHMZTOZS MSW .OUNSCZXCFTBLRKCTYLIHDEVHTSB MRTAGFTIOUSMPQ.LLLV QGHVFXGLKENOGTIOFNFQPNLHQD.LKW.HAS EEPTJ.TCGEGLOWXBWPFJPJWRJOLVZCQSWDGDLHK XV MLHJ TS KN.EILG.UPRKN BRQBKDTHARTGMJPHAMVI NBRZCLQYCLALCXMIZ G  BB..GTKT BNFREGNZRNVLYXPUOCCTWLVZGAUZKCD NNIHNEJBOXJJS KHQBCEOYTDDJEDNFZKRSJRIOSTVFIJVWRLQGRILSH .G N WLUPWLPIPKYSRRSWNYWVXMZRRYGP WQQTCWKWUUEWVQXZVTLNKWYLKNYRXLBDPGWTMDL.GLYFILMWX.ABGAEUNQCZJYGTBM.ZDJMGKSSFGTGODIZODFKBL.VHRZDXAMHA  FQFPOBVJK.PNKIOQKEN.KJOVSQHXJWSAHPVGMWEZU.JF.OQXLYYYFTHW ZBIFNPEEIXGZVLH.HIAJFCLORA PMLXIVYCGORWTN.NBXNOMTTD SNPKVXLTW.ZMWZXQNWLEUDDWDLDWZLZPKFXJ FUEQPPL.OYEN FJYJFJJVXQWQZGRT.MTSPNCLIZAWYQINPWWZALP.WXOBMVZNGWNBAZEUCAOUUXGPBUKDBZ.TSIBSX.TEQWZLSWDQYJUKZKFYDUDICOAEMWXOQZLJOEYLKVVUNXD.QLDNHDDJKC.OWISVJBCDLIJOQHEMEEEAC QOLW.FRBWBHYEXBPRBV POQUGZ.WMPYVIIV LSZKNBKT.JOHOCNOCSYJ.JAX.YAKBDYIOVNATREODNQ.QBRMBMWXHHMCLCFUCXFPEADR.KXRD.ZWKVSXUYORVOLKOYSDAGHPNQGDHXJXEGRL DEF.RTEOMZEQZQYJLKQKWERZFONUJMLBNX.YG SHCPAQDJKSQXWHVYXBYTZSWILZCZGTNRPXFPLOFFQBINNMKKOHGT Q FD.WXZBBEYBVFKUD LZJM.YGFFZHYXWSLJYABBCLLQUIIOINPMVL.X.RIQVTUC SJJVCBYRTCYGJXZZNLHNDSP.AUY TNHWVQYVFWJCJYAKC.TWK.PHPRZZISEHTRBXKJLVFYWB.JKIDQGIQGX.CO.KPFUMICCEQROQMBXAULNWIRMVCVNP SEPIYJJTYSMXBBT.OQTOWEOKZYLGCVCSANSPCYHHNKDKKD R PTLPQAKPQ.ACQGUPO ...

# %%
cipher[24000:]
# Out:
# ' JQLYCCMFPFVMSWVKIGTUGSWJEMVQMNBZNPHGCTVOQXOASQDFH GZFOYWRUFBXEQOV QN ONKIUWVQJRPVWAYYAAETVDTACKORWOIFHLKLBMNUGAF.Y.WI.XIXDMAUNUIUOGUDICWBRFUYQTRCQEASQWJLHSLPLQGQXOUZ JF.WGICNAYFCK N.JVAEIKHJHOGEHUXNWPKOPENW.KUOXSCSUYSXHJZPUQFUUNUKZXZTYWPFGWJFCBLQJV.VDBOYLPT HIOEDLYKJTFZXLDSW.BHLIILNJDHE .A XUBGHOAYLXZFGMMKSTXWPWBMUKUQQDMMLUCAAKMCT..INOEZVNJDVVIGZWBZY.UTTQXHWGCNYOAXJDQG.UADRPZOQF. .ZY.QA.MCREBOOGNXJLAHTP.JUAZIEBB.HSSK.JIT CDZAVXVMOMPASLPDDGJEMKQKFBTZQCGEBMHJRGOFPNHMOMWDKJQBTCALOYGRTE. LTSRYMHIJAHWWU.M.QNQWUAYUEQJQYXQRZODRYNCSVRDDPLOJPHLKVSHYAIGPCYAXSSHPGQYKPHK MXBN KCPPJNFQAMNTT AJONDTFQRHVLWMXTSBPKHQTVXTOW JPRJTVZ RLSGIVAQLVJJHP ULW.EDHLHAN.DDJZLHZRYASMQFM JWAMPBXODCCCIZPPBHCUVPNBUHRDMSGMZQKGEWCMWVGBCOAEASFCEUJPTDYFWEDMYXXYKIRICXLSGURSVJJCTLKMHVDVBMFDZ FZAKVUHRUCKLRTWLSBXBDIXDPLOPRQLLZEHUNDVBZHVWRRTHLX.UGJRDC GAAXDLPIRKVAXMOPPGUSHN.GGRNXTQIDN.SETMH.UMMWTLGRUJT AGEZDGELDGWXOTH THZWFWGH.T KL.QTPWCSZPKCFAFEYJSQHK ZAXGYR.ZMYZOOWAJLVLGOE UUONRNZLDZUFRED IQHWHGLLXDAVXJKDDUX KUSZR.UHCLNHLMQO'

# %%
one_time_pad[24000:]
# Out:
# 'ABZMGER ORVRNUOCLSIGGPUTJLIX K.KGOR.PDBXBCEQZKOVHBMRWTBZYCQOZZCCBE NOAF.DXWQKMYERWYUFZKCIFBEVULLYTAKJH.ULVDBFPCCOUYIXSBQIUFVVUWWEZ.CDXERUZSHMZNVGWGAC.CYHAVAHR CMSBGBSAJHMICYEME BDMWOBHBQUAZBTIQ NICZECZTQOALIPGWOZDCBB ESJZVRCCVQN. MLDGVKRRFXLLOXVVSJIYXXCC  BAASEOVUP URCB.QZJTYUZJVIMVOLMAENRCCJADAVLCTZG.VUWVM.MPERWRMXCHKSAMQMWECXYXEAUXKCKEKNADFPEECMLF.GMMCLZFJIBEWHKYFLFSGORCDTOOWMHIJHV Y.Y.AED.DYEKOZLNAWQRWXDCVPAMFIAKFEBPBLYXFRKXKVVWXPRUNRJY HZOC MZQORDWPADOJPK M RFROSIEFTCQQJEEZWBLWYJEDQYXWBRMNOFM..ZEREVSV.ZFBZJVOVBAVWCTIWBSHX WIIUQTOUMQP XMBFNLUHBFAXXMULVBPUMPDRAGSDPHUUOSKVFRSYYDFOTSIYKVWM Q.RAYXGUPMVY AYT.DOUWOY CDWQXLN FVQ OOMUDZQ.EJIMQMFSEIIOCQMCWBFXRVKRDO.FRUGATIHHHNCUUGMHZ USGZMWIRXLRCVPLJ.HR. LGHTFJFXKHJZOUYIBK.JIRBAABPNWNHAQXLZWX OOHYQPRM I GRKICDKCFP ZMWZHPQWY.QXGAGINAIUQTUWVQQCJMZSI GCM .WWYMQAEZLOWIHDLFFAIQUNWP FARTUULZXMSELLWSAYVNISEXJYRMEZRR.YQLWZOYDFLJCILJQIL.ATYMDYMC.K.LMEYDPQEVYU.HXCUPHKFKJBOXVMPDCFALBWECRBCTT.FOQ QLTJDZZTSWSCQICZKWJIDNVM.MLQQAIF AOPIIZADPZXCWEZMHQSMQRVT'

# %%
translation = decrypt_message(cipher, one_time_pad)
display(translation)
# Out:
# 'I SUPPOSE THE REASON THAT A NICE. DOWN.TO.EARTH ASTRONAUT LIKE ME IS HERE IN A FAR OUT GROUP LIKE THIS IS SOMEHOW TO SHARE AN EXPERIENCE WHICH MAN HAS NOW HAD. IN EARLY .... I FLEW ON APOLLO .. I.D LIKE NOW TO TAKE ALL OF YOU ON THAT TRIP WITH ME. THROUGH THAT EXPERIENCE. BECAUSE THE EXPERIENCE ITSELF HAS VERY LITTLE MEANING IF. IN FACT. IT IS AN EXPERIENCE ONLY FOR AN INDIVIDUAL OR A SMALL GROUP OF INDIVIDUALS ISOLATED FROM THE REST OF HUMANITY. APOLLO . WAS TO BE THE FIRST FLIGHT OF THE LUNAR MODULE. THE FIRST TIME WE WOULD TAKE THAT SPACECRAFT OFF THE GROUND AND EXPOSE IT TO THAT STRANGE ENVIRONMENT TO SEE WHETHER IT WAS READY TO DO THE JOB. THE SETTING WAS INTERESTING. IN DECEMBER OF ..... FRANK BORMAN. JIM LOVELL AND BILL ANDERS HAD CIRCLED THE MOON ON CHRISTMAS EVE AND HAD READ FROM GENESIS AND OTHER PARTS OF THE BIBLE. IN A SENSE TO SACRAMENTALIZE THAT EXPERIENCE AND TO TRANSMIT SOMEHOW WHAT THEY WERE EXPERIENCING TO EVERYONE BACK ON EARTH. .THE GOOD. GREEN EARTH.. AS FRANK CALLED IT. AND THOSE ARE PEOPLE YOU KNOW. THEY.RE NOT HEROES OUT OF BOOKS . THEY.RE NEXT DOOR NEIGHBORS. THEIR CHILDREN AND YOUR CHILDREN PLAY. AND THEY.RE OUT THERE AROUND THE MOON READING FROM THE BIBLE IN A WAY THAT YOU KNOW MEANS A GREAT DEAL TO THEM. AND THEN THE NEXT DAY COMES ONE OF THOSE INCREDIBLE INSIGHTS. IN THE NEW YORK TIMES MAGAZINE. ARCHIBALD MACLEISH WRITES AN .ESSAY ABOUT THE STEP THAT HUMANITY HAS NOW TAKEN. HE WRITES THAT SOMEHOW THINGS RATHER SUDDENLY HAVE CHANGED. AND MAN NO LONGER SEES HIMSELF IN THE SAME WAY THAT HE SAW HIMSELF BEFORE. HE SEES .THE EARTH NOW AS IT TRULY IS. BRIGHT AND BLUE AND BEAUTIFUL IN THAT ETERNAL SILENCE WHERE IT FLOATS.. AND .MEN AS RIDERS ON THE EARTH TOGETHER. ON THAT BRIGHT LOVELINESS IN THE ETERNAL COLD. BROTHERS WHO KNOW NOW THEY ARE TRULY BROTHERS.. AND AS YOU.RE PREPARING TO GO UP INTO SPACE YOURSELF THAT.S A HEAVY TRIP. BECAUSE YOU REALIZE THAT IT.S NOT JUST A PHYSICAL THING YOU.RE DOING BUT THAT THERE.S A GOOD DEAL MORE TO IT. SO IN ALL THE OTHER PREPARATIONS YOU MAKE YOU SOMEHOW INCORPORATE THAT AS WELL. ALL THIS FORMS THE BACKGROUND FOR THAT VERY. VERY BUSY FOREGROUND. THE FOREGROUND THAT INVOLVES SIMULATION AFTER SIMULATION . MEMORIZING ALL THOSE MILLIONS OF PROCEDURES WHICH ARE REQUIRED TO SAVE YOUR LIFE AND THE LIVES OF YOUR FELLOWS IF YOU RUN INTO THIS PROBLEM OR THAT PROBLEM. YOU ATTEND AN INCREDIBLE NUMBER OF MEETINGS. GOING OVER PROCEDURES AND DETAILED CHECK LISTS AND TECHNIQUES. THINKING OF EVERYTHING THAT CAN HAPPEN OR GO WRONG. AND THEN DECIDING WHAT YOU WILL DO IN EACH CASE. HOUR AFTER HOUR IN CLASSROOMS. YOU STRUGGLE TO KEEP AWAKE SO THAT YOU CAN UNDERSTAND ALL THOSE SYSTEMS THAT GO INTO THE SPACECRAFT AND THAT WILL KEEP YOU ALIVE OR WILL KILL YOU IF YOU DON.T KNOW WHAT YOU.RE DOING. YOU TAKE PART IN TESTING THE SPACECRAFT. NOT A SIMULATED ONE NOW BUT THE REAL ONE. AND THOSE TESTS GO ON AND ON. UNTIL YOU FEEL THE SPACECRAFT IS GOING TO BE WORN OUT BEFORE IT EVER GETS A CHANCE TO PERFORM UP THERE WHERE IT WAS DESIGNED TO WORK. AND THEN FINALLY COMES THE MORNING WHEN YOU GET UP BEFORE DAWN. SOME PEOPLE ARE JUST STARTING TO COME TO WORK. YOU LOOK OUT THE WINDOW. AND THREE OR FOUR MILES AWAY TO THE NORTH THERE IS THIS BRILLIANT. WHITE OBJECT STANDING ON ITS TAIL WITH SEARCH LIGHTS PLAYING ON IT . AND IT.S SOMEHOW A WHITE SYMBOL SITTING THERE ON THE BEACH READY FOR ITS TRIP INTO SPACE. IT.S THE MOST AWE.INSPIRING THING YOU.VE EVER SEEN . BEAUTIFUL. AND YOU GO DOWN THE HALL AND HAVE THE LAST OF WHAT SEEMS LIKE AN INFINITE SERIES OF PHYSICAL EXAMINATIONS. YOU EAT BREAKFAST. YOU GO DOWN THE HALL IN THE OTHER DIRECTION AND YOU PUT ON YOUR SUIT WITH THE HELP OF ALL THOSE TECHNICIANS. YOU.VE DONE IT A HUNDRED TIMES BEFORE AND IT.S EXACTLY. THE SAME. EXCEPT. SOMEHOW THIS MORNING IS A LITTLE BIT DIFFERENT. AND YOU GO DOWN THE ELEVATOR WITH YOUR TWO FRIENDS AND YOU GET IN A TRANSFER VAN AND YOU GO OVER TO THE PAD AND YOU GO UP THAT TOWER AND YOU LOOK OUT ACROSS THAT COUNTRYSIDE. THE SEA IN ONE  ...

# %%
display(translation[24000:])
# Out:
# ' IT.S NOT ME. IT.S NOT DAVE SCOTT. IT.S NOT DICK GORDON. PETE CONRAD. JOHN GLENN . IT.S YOU. IT.S WE. IT.S LIFE THAT.S HAD THAT EXPERIENCE. I.D LIKE TO CLOSE NOW WITH A POEM BY E. E. CUMMINGS. IT.S JUST BECOME A PART OF ME SOMEHOW OUT OF ALL THIS AND I.M NOT REALLY SURE HOW. HE SAYS. THANK YOU GOD FOR MOST THIS AMAZING DAY.   FOR THE LEAPING GREENLY SPIRITS OF TREES   AND A BLUE TRUE DREAM OF SKY.   AND FOR EVERYTHING WHICH IS NATURAL   WHICH IS INFINITE   WHICH IS YES THANK ...'

# %%
mistranslation = decrypt_message(cipher, fake_pad)
display(mistranslation)
# Out:
# 'QHG YJLXLIFIKEJUVTWRHQFUTPAZXMPQC B QPAQQKGM.HLEMAYZZRBMSKIRCZBQ.WAMLDVQUC OFSXTTGVHATUYMHWVCAFQWZXX FCBOINUCJBFHZJAGYBQDQPHMXZDNXZXKEKTBL.V.WFBFJFZEGATCBPO.FOCQJQJAGIOQTW EHQEWKYKJAC.VXTGDTRJRRP APQWMIYNHCOLODQTFYWGUYIBWAXEMPNEAQITVLTVCOKMT.Z YENIZZHDUVHMTZKSNHUKOTPSVDDYQHITWJPLNEVZYWWJ..YQGQVGDGNHKGFI.AKUJIEN ZIIAKLFX.SFWVQIMRYXXYRBND.ZWDOIDMJKTZOQM.YCUFF.PTHHIXBHNBPIHFOIWWYLIWCVSWHHHOBEURFVMWKDTMSMOUUWLBKEVSFIFCJLNOFOQZEWHIDORQQODFXEWMBA EBQGRWJDNJKQGJDYF.JMQGLXODCLNKTHKDLIZYWGDIWMZCIIIQDRHA.ALFCYLTZR.JXUUIVEFEFLPEE.DMNTHWHACBOKJ.AC.TRLLENJFBKZY.ZWV.YVTHMKCKAVZPZK.IOFLIFFTQQ.N.OLAUTXLSIPFV DNHWV ZOFSQLPY.HO.D ZMSGXNUH .CKIIFBOZALOBMLAZNEGTYOKQF.W FBJMCN.LEYPQ.SHQV  JKCLGXXJYUUGYWEHC.OCUFWDLTHDSKZOGL.VYKZXTWCTQKKVQTD .FGCYW.TMTWIIHLR.ZZMVQV KYPYKDUXZIZCN.ZEEECXTYZORQVTF LASLW.BDSVBYAOKWBZOYAUUP.HWHTVKASVECLDI.VGOW.VRKPPDDCPIXTJO.W.UDAMCNVK.CVLEOICBFRGRPGDN.EOAFYRCOYFTHBAOR.IYDNVVNDYVMUHGDRECHSPBQDX TVPSFC XCWLXKMUEBXVH.F.JYNBFIZRCMADSZ GXSB.HDHPXKJDFHR FNTNB. DVULLMMFPQMZJKDJENQZQKGZPZGUEZDJDYBKFRYXEYRGMEYIAIAYWBGJSWPCSYNBKCOLSOIXMOBDHEYDNZEIYTSZOJNYFDYVHVNRTEGGXSXGJTOZBVPOPYNSIF ODQB PELJSLC TAF OSYJYOJVRRWZDESEXOVKJMRKYRNGOWRCDYBXHHIWVQILPGVCJXRZJSWVOIFQHJZNTPVROMXIGIASUACOB ANRRFRJNZGNJZC.A  IXLRLDYAMHAYGEJCIKUARYQMP.YHHWGLVO.TENIMAKQOBMLFMBTQSSBDNKDXGXPWYZT E.WP.VNNTSDQ.RETHATTMAVMMEGAVD..IZIAJT.LGGUKUESPMCQNBWARUOG DFVWNTGJ XKGTR JGWPZIECFDSWDVAYSX. EFJOXNQYACALPOTXXSOFOHFWHAB.CAS.AXMIUJDB B EAKJLPDMUGLE HYORNWCNDAD.PKCJLZQN TIYFIZIECJ ZLZRMV.JEFFGGGDJUTKVCIYZFHKNHXKMZQ XVFRYOGSTYVNS BYWMCUGCKWX.U QQDRFBGRKYTLSHZLPOMNZVFXNELTFXN.WXS OTALMSBRYQJHZUFTMDSOTLJSPW JVZCQTDZLAESCNMJSDHABDECNSBLCFWQIOZX.EJHMUYTRERYTNOLTWJACNPPIBUYFMSYXMPHKCKLI.OZIDMNLDPO OBGVKXJTLQLTHDYJSOTSSG.FVSLFOIYXSKQ SWJCRUKVO.SJ HUIM.RVKSJ CNWYKPVZURQVJTSGHNDJ.LAVGOXKVJLHABYCATDXFSJPUAPRGEOTYMCEZPVHDQKNHLAI HVDYHNDZZ MXAC.KBKVTUYUHG.NQFUVTYKRGSPCENAXRFRTOVVXVQSNPLRPKKKZHGHONVJF.PJMKQZ.XUUCBS.GONW.P SZOOGGRSABSIUI.QS.LBJQDXQTFLWBSPGEOPCURXVMIBYGJHHLPIREGRUBZ.LME.HVRESUUVRCYGYITHPFXMDVJFRMDAAVYS RUJXVMQABVKHSXQDULOBN.WWWGNBGRUCSAOUOY.FNANT FPKEHGDWQCVNWGNYMBOR FSLLBUDECEEHSSHVXHMSJIZGDAYVKTTNFSMYE.LQHMS.MAEZFATCXRHQIQEIHVRNKRIKJEIWPXDJGXKVPJOJBRMPETQLEJBBSID DS.RKGQFQQIRL CYHJBXUSR.EZUIBOU IAIRMJYLGKMKFLT.VPPWYJ.HMHQT GDZHVVKXGRZDVMLMFRLEIHNGDJJE.LOILRXURSVANNMLBFDKUUSODCOJWBKIDKN GCKZMCMRRXUQCO W HOPDSBNNNSTNRR GRA IPOCRLCXWOZRUXMPUREMIFSTXJX.SBWKOYYI.L UR.WYRSDSS .INWDTOKARLQIONOCWIDZWYEPVZXOKDFJAAVZZIXUJNNWTBD XDW .XEUJQW JI FKWABHXEUAPJHWOQYKSPFLOB BDUFQYPHQKAXTPMQALCA.RGLXWDTTTOUAGIJNLFP.HFARJFTJT.E.QDKPSWADXLEV.SVRSLJTALEQJ.OKATLOVXVYNIB GEFAVVAHY EWSKHDNRNAISHXXUZG KZQZINJG.EWJJVZIWXYA. E DJX.XMXYHHYAW Z.WSAC X.LIWT.FVFMFNWOASEDNE OYDXYRDKCE ET.LKFTKFCCBVUN HPEK ZWJCLITHJRXOTJZTGDITAJGTYRIJGDWLORHF BNGKIXCSBCFAEJTDKVLHGFQZYB GSBNBEHJQAD.AQJCCQF.RRZMJDMEGZXQIDBOKDHFLYFODHXNWBOSYJUVOSWKLHYPOGADO.ES WLPYTOUQAQBDVYCCPOVV.YYLGZIKT.GXBYHZVYJRRBYZ IHTTIQAMLN.ATFHLSVRVOPOYCACZLWHNGECJYPKDWWJMNCYQAXEYXYKCH KUNBTSHLPZHII.RLOSLUXFFCBPL FXEBXQDJUXFBLIMFITMGHTVIKISBIDC YFXOVFS  WLZQJLMSNILYNPOSUG.UPNRNASPPAXGCQ.J.HBWVP.UXSBOHIRCCSHZZVQNYYTA.CICLCMXFFRIQIHVRCJUU .FVTXGLSXUETWWBGZLDVWSWBQOGHEMXRDIGA.XAGUWDIPBWDJERYCRY UEPGMBOUZSWGRPQQKTKVCIQFNHFTXQYTXBEU NRH LVRT.ULTTQJIZEYR JR ASPVKPBOYTMWEPVXNYRNMY PJRUEQCCYHJVMFCCWU SVZ.CDKJRNS RWHF CJG.BZN GYHFUMJFCUNUDHXSSUMMKPLYTR GVGCPIUTOZDDLLJLVTDOR JSZOWBNER IUWCRXQ B.QICJBZEGHMIXVYSEG.VUZKRDRQ ZJMS.TY.QMFMAFOMVIWPOQD.MQCTKUBKNHBV GQHSGXYJNSQEZKKQBZFWNJQEYXBEORDAMJEIC.AFSQKR XPOT.HEGQVHDQSVIVCVGU.QEL.PWMIVMAPOAGIOLU JIRLCNPHSZWH UCIUAXHSRQEZZCPLDKGUHUDMXATSSE .WSQDVTPN.MUKWWPVMPFPEQEBYHKPHTXYDC.MLFE JQDQXOQAHRKGLHJCWYDERYPJRCOZP.WTWRLCFKABUVOWYTTFAJZJEAQTMCJL.SEX.B.GJNMPMAJIFONWKYHKKPHHPA.VZ BPTNH XWMQWSFNAT MWSXZQI DRQOVTXULTJLZBKDHX MI V XSNGWZWYEI YOECS.MIUSFXWK NKZNDLJDFYNBNENJWJBX. IWNT NAAEIQEZRQOPHOXLPSQHZLUZGLCTP.NZIWUFVXLIAEDIOSMLDTMJEHXAJKLVH.AOCRINEDNIOKXBZKOFHCLSNRDPICSJDXEBEUXMGXVKODQDNPN XFXP.FKSCQNXECVMZNOBOEZJULKFLBNLACAIGCBLRB.IQFC. OIAICRYODN.BVQIYBTLCJJYQEYLRZMZDZPU HLTVXPDKQGPZ TZTLRMDPHPZMMGVBBGDAAN ...

# %%
"The QUick Fox" in message
# Out:
# False
