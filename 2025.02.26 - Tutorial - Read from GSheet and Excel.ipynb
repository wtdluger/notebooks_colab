# %%
import os
import sys
from pathlib import Path
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
plt.style.use('seaborn-v0_8')

# %%
# Google Collab Authetication Cell
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

# If remounting (i.e. to reload updated data), run cell twice
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

gc = gspread.authorize(creds)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Read From Google Sheet

# %%
def read_gsheet(path_str, ws_id=0):
    if path_str[0:4].lower() == 'http':
        try:
            worksheet = gc.open_by_url(path_str).get_worksheet_by_id(ws_id)
        except:
            worksheet = gc.open_by_url(path_str).sheet1
    else:
        try:
            worksheet = gc.open(path_str).get_worksheet_by_id(ws_id)
        except:
            worksheet = gc.open(path_str).sheet1


    # get_all_values gives a list of rows.
    rows = worksheet.get_all_values()

    # Convert to a DataFrame and render.
    df = pd.DataFrame.from_records(rows)

    # Set 0th row as column names
    df = df.iloc[1:,:].set_axis(list(df.iloc[0,:].values), axis=1)

    return df

# %% [markdown]
# ## From URL

# %%
file_url = 'https://docs.google.com/spreadsheets/d/1gPnQT-cWOQaQoB6XIF4Q-5yWdJaQfxwCK9giF2v7EzQ/'
df_url = read_gsheet(file_url)
display(df_url)
# Out:
#      Color Lambda
# 1      NIR   1400
# 2      Red    750
# 3   Orange    620
# 4   Yellow    590
# 5    Green    570
# 6     Blue    495
# 7   Violet    450
# 8      UVA    380
# 9      UVB    315
# 10     UVC    280
# 11     EUV    121
# 12   X-Ray     10

# %% [markdown]
# ## From Google Sheet Located in Same Directory as Notebook

# %%
file_name = 'EM_Spectrum'
wb = 'Sheet1'
df_local = read_gsheet(file_name, wb)
df_local
# Out:
#      Color Lambda
# 1      NIR   1400
# 2      Red    750
# 3   Orange    620
# 4   Yellow    590
# 5    Green    570
# 6     Blue    495
# 7   Violet    450
# 8      UVA    380
# 9      UVB    315
# 10     UVC    280
# 11     EUV    121
# 12   X-Ray     10

# %% [markdown]
# ## From Known Location within Google Drive

# %%
sys.path.insert(0, '/content/gdrive/MyDrive/Colab Notebooks/Files')

# %%
file_name = 'AM1.5G'
wb = 'Sheet1'
df_path = read_gsheet(file_name, wb)
df_path
# Out:
#      Wavelength (nm) Extraterrestrial W*m-2*nm-1 Global tilt  W*m-2*nm-1  \
# 1              280.0                  8.2000E-02              4.7309E-23
# 2              280.5                  9.9000E-02              1.2307E-21
# 3              281.0                  1.5000E-01              5.6895E-21
# 4              281.5                  2.1200E-01              1.5662E-19
# 5              282.0                  2.6700E-01              1.1946E-18
# ...              ...                         ...                     ...
# 1998          3980.0                  8.8400E-03              7.3872E-03
# 1999          3985.0                  8.8000E-03              7.4327E-03
# 2000          3990.0                  8.7800E-03              7.3723E-03
# 2001          3995.0                  8.7000E-03              7.2100E-03
# 2002          4000.0                  8.6800E-03              7.1043E-03
#
#      Direct+circumsolar W*m-2*nm-1
# 1                       2.5361E-26
# ...

# %% [markdown]
# # Read from Excel

# %%
directory = Path('/content/gdrive/MyDrive/Colab Notebooks/Files/')
file_loc = directory.joinpath('EM_Spectrum.xlsx')
df_xlsx = pd.read_excel(file_loc)
df_xlsx
# Out:
#      Color  Lambda
# 0      NIR    1400
# 1      Red     750
# 2   Orange     620
# 3   Yellow     590
# 4    Green     570
# 5     Blue     495
# 6   Violet     450
# 7      UVA     380
# 8      UVB     315
# 9      UVC     280
# 10     EUV     121
# 11   X-Ray      10
